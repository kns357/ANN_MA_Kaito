# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open("testimgcustom.png").convert("L").resize((28, 28))
img_array = np.array(img) / 255.0
inverted = 1.0 - img_array

plt.imshow(inverted)
