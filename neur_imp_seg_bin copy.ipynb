# %%
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import random as ra

# %%
input_size = 784
hidden_size0 = 32
hidden_size1 = 16     
out_size = 10 #binary for whether it is digit or not
        
epochs = 10            
batch_size = 1000 #just for loading more data easily
learning_rate = 0.001

# %%
train_dataset = datasets.MNIST(root='./data',
                           train=True,
                           transform=transforms.ToTensor(),
                           download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=batch_size,
                                          shuffle=True)

# %%
test_dataset = datasets.MNIST(root='./data',
                           train=False,
                           transform=transforms.ToTensor())

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)

# %%
class Net(nn.Module):
    def __init__(self, input_size, hidden_size0, hidden_size1, out_size):
        super(Net, self).__init__()
        self.fc0 = nn.Linear(input_size, hidden_size0)
        self.fc1 = nn.Linear(hidden_size0, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, out_size)
        self.relu = nn.ReLU()
        self.init_weights()

    def init_weights(self):
        nn.init.kaiming_normal_(self.fc0.weight)
        nn.init.kaiming_normal_(self.fc1.weight)
        nn.init.kaiming_normal_(self.fc2.weight)
        
    def forward(self, x): #x = input img
        x = x.view(x.size(0), -1)  #flatten img, because (batch_size, 1, 28, 28) and nn.Linear expects (batch_size, features)
        out = self.relu(self.fc0(x))
        out = self.relu(self.fc1(out))
        out = self.fc2(out)

        return out

# %%
net = Net(input_size, hidden_size0, hidden_size1, out_size)
CUDA = torch.cuda.is_available()
if CUDA:
    net = net.cuda()

# %%
file_pth = 'binary_ffn_all.pth'
net.load_state_dict(torch.load(file_pth)) #pre-trained
# Out:
# <All keys matched successfully>

# %%
inputs, labels = next(iter(test_loader))
ind = ra.randrange(0, len(inputs))
img = inputs[ind].squeeze() #[28, 28]

weights = net.fc0.weight.detach().cpu() #[32, 784]
importance = weights.abs().sum(dim=0).view(28, 28) #[28, 28]

activation_fc0 = img * importance #[28, 28] 

plt.imshow(activation_fc0, cmap='hot', vmin=0, vmax=activation_fc0.max())
plt.colorbar(label='Pixel * ∑|weight to fc0|')
plt.title("Each Pixels' Influence for One Image (fc0 only!)")
plt.axis('off')
plt.show()

# %%
#shows that often most areas of the digit are important (in fc0, not at final decision), but if less is needed for a correct prediciton, weights do distribute accordingly

# %%
inputs, labels = next(iter(test_loader))
dig_to_check = 8

#search wanted digit:
while True:
    ind = ra.randrange(0, len(inputs))
    if labels[ind] == dig_to_check:
        img = inputs[ind].squeeze()
        break
    
img = torch.full((28, 28), 255).float()

plt.imshow(img, cmap="inferno")
#plt.title(f"Predicted by net: {pred}")

img_flat = img.view(-1)

weights = net.fc0.weight.detach().cpu()
biases = net.fc0.bias.detach().cpu()
contribs = weights * img_flat #32, 784

#mask = (img_flat > 0).float()
#contribs = contribs * mask

#contribs = torch.clamp(contribs, min=0.0)

#normalise to [0, 1]
max_val = contribs.max()
contribs_norm = contribs / max_val
contribs_imgs = contribs_norm.view(-1, 28, 28)

mask = torch.where(
    contribs_imgs == 0,
    torch.tensor(0.0, device=contribs_imgs.device),
    1
)

contribs_imgs += biases[:, None, None]
contribs_imgs *= mask #no bias where background = 0

contribs_imgs = torch.where(
    contribs_imgs == 0,
    torch.tensor(0.0, device=contribs_imgs.device),
    torch.where(
        contribs_imgs > 0.35,
        contribs_imgs,
        torch.tensor(0.0, device=contribs_imgs.device)
    )
)

activation_modified = []
for i, mat in enumerate(contribs_imgs):
    mat = mat.sum().item()
    print(f"{i}: {mat}")
    activation_modified.append(mat)


#combo = contribs_imgs.sum(dim=0)
combo = contribs_imgs.max(dim=0).values

#normalise
#max_val = combo.max()
#combo /= max_val

"""combo = torch.where(
    combo == 0,
    torch.tensor(0.0, device=combo.device),
    torch.where(
        combo > 0.35,
        combo,
        torch.tensor(0.1, device=combo.device)
    )
)"""



"""for i, mat in enumerate(contribs_imgs):
    if i == 0:
        activations = mat.sum(dim=0)
        continue

    activations += mat.sum(dim=0)"""
#instead take actualy activaiton, this is modified for visuals!
activations = net.fc0(img.view(1, -1).cuda()).squeeze()

next_neuron_idx = 5

weights_to_neuron = net.fc1.weight[next_neuron_idx]
contribution = activations * weights_to_neuron
#next_contribs = contribution.sum(dim=1) #dim = 1 means y-axis, so all weights to neuron

#print(next_contribs.size())
print(weights_to_neuron.size())

plt.imshow(combo, cmap="inferno")
plt.title("Combined max importasnce of all neurons")

fig, axes = plt.subplots(4, 8, figsize=(16, 8))

vmax = contribs_imgs.max().item()

for i, ax in enumerate(axes.flat):
    im = ax.imshow(contribs_imgs[i], cmap='inferno', vmin=0, vmax=vmax)
    ax.set_title(f'Neuron {i}\nActivation: {round(activations[i].item(), 3)}\nWeight: {round(weights_to_neuron[i].item(), 3)}\nContr. to n{next_neuron_idx} in l+1: {round(contribution[i].item(), 3)}', fontsize=8)
    ax.axis('off')

fig.suptitle('Pixel Importance to all 32 hidden neurons after fc0', fontsize=16)
cbar_ax = fig.add_axes([0.92, 0.15, 0.015, 0.7])
fig.colorbar(im, cax=cbar_ax)
plt.tight_layout(rect=[0, 0, 0.9, 1])
plt.show()
# Out:
# 0: 38.492061614990234
# 1: 30.312314987182617
# 2: 63.50591278076172
# 3: 10.32923412322998
# 4: 19.06449317932129
# 5: 0.0
# 6: 78.14423370361328
# 7: 26.5922794342041
# 8: 119.24308013916016
# 9: 38.64740753173828
# 10: 7.988775730133057
# 11: 0.4123058319091797
# 12: 40.33018493652344
# 13: 11.685239791870117
# 14: 6.469939708709717
# 15: 27.19940185546875
# 16: 6.44991397857666
# 17: 38.50137710571289
# 18: 13.83300495147705
# 19: 58.552162170410156
# 20: 25.6743221282959
# 21: 19.128864288330078
# 22: 21.449420928955078
# 23: 73.37361145019531
# 24: 22.968563079833984
# 25: 0.0
# 26: 104.47138977050781
# 27: 9.603487014770508
# 28: 14.49514389038086
# 29: 12.244003295898438
# 30: 32.58915710449219
# 31: 40.76224136352539
# torch.Size([32])
# /tmp/ipykernel_205055/2355662498.py:110: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])

# %%
"""complexity should be define as the appearance of one concept in another, one concept being composed more than one other, means it is higher-level, more complex. This lets me decide between any two concepts which one is more complex, if it doesn't in some case, then I have asses the compositionality with fitting, like the best way to cover one geometrical concept with another would result in one concept needing to be applied more times, the other being too big to fit it with >= 1 occurence, meaning that one is the more complex one. Two concepts may also be on the same level of complexity, if they don't occur in each other and their size difference is within a reasonable threshold.

actually, its about what could be removed and what is found in every example of the dataset. we humans, for some, possibly arbitrary reason, have learnt a bunch of criteria that we make sure not to miss when handwriting a digit. I have to find the segments in the inputs that cover these, then I have to find a sub-net that searches for the concept. I could just check all found concepts and check the activation for them, and then take those concepts that have a similar activation pattern and occur in every example. I could also mathematically generate examples, get the expected activation pattern, and then check which concepts it takes a similar activation pattern for.

so for the philosophical part: the concepts that humans define to use, are those that are essential for the definition of a digit, if its too high-level then it may not occur in every digit, if it is too low-level (like only a short line or curve segment) it may not be defining for the digit. The relative location of it is also important, as the spatial combination of these concepts can have essential properties as well, meaning the concepts used to define a digits are not fixed in complexity, they just have to occur in every digit of a class, and make the model confident in class prediction, and occur in the right combination with other concepts, meaning it has to be in the correct spatial relation to them. I can find these by getting the activation patterns for all extracted concepts of many example inputs, and can then search for recurring and similar activation matrices, which hopefully shows me a human-identifiable concept that is essential for the digit and is not too small to define this digit specifically, but also not too big to be reappearing - actually I just noticed it can be a higher-level sub-concept but still be recognized repeatedly despite variety - it seems that the concepts humans use have a lower boundary (they must still be specific (not necessarily exclusive) to the digit) but no upper boundary, as humans simply think in statistically frequent patterns, which the network has no way of knowing - this means I need to specifically look for these, that means I can still find a sub-net that actually recognizes those, but I need a smart way that requires as little human intervention as possible.

something defining the digit strongly means the concept feature is very unique to this class. that means I would have to search concepts that do not exceed a certain pixel count but are unique to the class - I could search the ones with the lowest pixel count that are still unique to the class. Then I would need to take the activations as a matrix and compare it to other such concepts, to find the similarities in activations, meaning the sub-net that activates on those concepts specifically. - actually I just realized those are separate, I can get the activation pattern for any concept, and try to extract a net that activates on it. it is a separate task to find the same feature across different inputs - actually no, that might require the activations, but I don't know which neurons should be similar, because the others may be different - damn, that's tricky.

size doesn't necessarily define uniqueness, I just have to check to make sure the concept is mainly activating in this class, which means the full model prediction must indicate it, and the internal activations should not be found in concept segments of other classes, but in most other inputs from the same class to make sure it is a defining feature for this class.

I now have an improved concept extractor using dfs that gives me around 20 to 30 concepts, though these are not too large by themselves, only 10 pixels, meaning I will have to recombine some concepts to get bigger concepts more quickly

now to find the sub-nets that detect certain human concepts across multiple examples, we need to find an effective way to extract the wanted concepts
	idea: this is about showing that the net learns human concepts, so why not let the human play a role in defining the concepts, as long as it is not too inefficient, it would be important, and it doesn't matter what concepts the human defines, it may define any concepts and it will simply be about showing how the net detects them. what will be of importance though is to show which concepts are essential to define the digit. I will still look into how to more precisely define these, similarly to how I did it before.
	more importantly though: I will need to find a sub-net that detects a given concept. asumed is that the net is already trained, so finding it for one example of a concept may imply it can detect other variations of it already. though finding it might mean it has to be one that does detect all variations, not only this example, which make the search a bit ambiguous - we may find multiple sub-nets activating on a concept, only some or one of those may be the generalised one(s). 

-> it could work because fc0 attribtues importance of each pixel combined into a neuron, which then leads to some neurons not being involved in the sub-concept at all, zeroed out, some partly or almost fully  but still partly involved -> these are still have activation > 0, which will still be lower than if other pixels were also there to further activate those partially concept focused neurons, but exactly this difference in activation carries the information about which parts (the conept) are still there, different neuron lost different amounts of activations, all coherent to which parts have stayed and which not in the input (in isolated concept). now if I look at these activation, I have to note that the net is alrady trained, assuing the net had to or simply has learnt to recognise and use for prediction the given concept, it would have to have some neurons activating differently because of it in l+1, after that there may or may not be more information about it, still should be checked out, but regardless I have to search everywhere for the sub-concept prediction. I could try to craete in addition a neuron that has weights strongest weights to the highest activated neurons in l-1, l would consist of only that neuron, new dimension, not the regular l+1 relative to l-1, which is called l here, but more like l+i -> it would check the stronger indicators of the concept more strongly, proportionally so all the other neurons -> it might indicate other variations of the concept similarly too
# !! important !!:  the definition of the concept space is not define, as no large enough dataset nor a trained net (which would likely imply such a dataset) exists
--> this means we could and maybe should use the activations as concept space, meaning all similar activation patterns or ones that activate the extender neuron, can be considered the concept. if that works (checked by human concept recognisers) I would have successfully used the existing but fully hidden knowledge of the trained net about sub-concepts, not having to teach it anymore, but having to extract them by search! The activation similarity could be based on weights to th eextender neuron, i.e. the biiger a weight, the more the difference of the corresponding activation is valued in calculating the difference!"""
# Out:
# "complexity should be define as the appearance of one concept in another, one concept being composed more than one other, means it is higher-level, more complex. This lets me decide between any two concepts which one is more complex, if it doesn't in some case, then I have asses the compositionality with fitting, like the best way to cover one geometrical concept with another would result in one concept needing to be applied more times, the other being too big to fit it with >= 1 occurence, meaning that one is the more complex one. Two concepts may also be on the same level of complexity, if they don't occur in each other and their size difference is within a reasonable threshold.\n\nactually, its about what could be removed and what is found in every example of the dataset. we humans, for some, possibly arbitrary reason, have learnt a bunch of criteria that we make sure not to miss when handwriting a digit. I have to find the segments in the inputs that cover these, then I have to find a sub-net that searches for the concept. I could just check all found concepts and check the activation for them, and then take those concepts that have a similar activation pattern and occur in every example. I could also mathematically generate examples, get the expected activation pattern, and then check which concepts it takes a similar activation pattern for.\n\nso for the philosophical part: the concepts that humans define to use, are those that are essential for the definition of a digit, if its too high-level then it may not occur in every digit, if it is too low-level (like only a short line or curve segment) it may not be defining for the digit. The relative location of it is also important, as the spatial combination of these concepts can have essential properties as well, meaning the concepts used to define a digits are not fixed in complexity, they just have to occur in every digit of a class, and make the model confident in class prediction, and occur in the right combination with other concepts, meaning it has to be in the correct spatial relation to them. I can find these by getting the activation patterns for all extracted concepts of many example inputs, and can then search for recurring and similar activation matrices, which hopefully shows me a human-identifiable concept that is essential for the digit and is not too small to define this digit specifically, but also not too big to be reappearing - actually I just noticed it can be a higher-level sub-concept but still be recognized repeatedly despite variety - it seems that the concepts humans use have a lower boundary (they must still be specific (not necessarily exclusive) to the digit) but no upper boundary, as humans simply think in statistically frequent patterns, which the network has no way of knowing - this means I need to specifically look for these, that means I can still find a sub-net that actually recognizes those, but I need a smart way that requires as little human intervention as possible.\n\nsomething defining the digit strongly means the concept feature is very unique to this class. that means I would have to search concepts that do not exceed a certain pixel count but are unique to the class - I could search the ones with the lowest pixel count that are still unique to the class. Then I would need to take the activations as a matrix and compare it to other such concepts, to find the similarities in activations, meaning the sub-net that activates on those concepts specifically. - actually I just realized those are separate, I can get the activation pattern for any concept, and try to extract a net that activates on it. it is a separate task to find the same feature across different inputs - actually no, that might require the activations, but I don't know which neurons should be similar, because the others may be different - damn, that's tricky.\n\nsize doesn't necessarily define uniqueness, I just have to check to make sure the concept is mainly activating  ...

# %%
#activation function can be ignored, as it is ReLU and this image is normalise by setting negative value to 0 already!

# %%
#!NOTE TO SELF: ONCE DONE, REMOVE CERTAIN PATCHES FOR DECISIONS, TO SHOW THAT THIS PART WAS IMPORTANCE, AND USE EXAMPLE OF E.G., 3 VS 8 WHICH SHOULD BECOME HARDER THEN

# %%
#next steps planned for thu: segmenter for relevant patches, make class cinstruction for concepts, make indexing system to trace activations through FFN, start summariser system to reduce FFN, check FFN accuracy with reduced paths

# %%
"""import torch
import matplotlib.pyplot as plt

#Parameters
imgs = [x.clamp(0, 1) for x in contribs_imgs]
value_thresh = 0.9
loc_thresh = 3
groups = []
used = set()



for g_idx, group in enumerate(groups):
    plt.figure(figsize=(len(group)*2, 2))
    for idx, img_idx in enumerate(group):
        plt.subplot(1, len(group), idx + 1)
        plt.imshow(imgs[img_idx].squeeze(), cmap='inferno', vmin=0, vmax=1)
        plt.axis('off')
    plt.suptitle(f'Group {g_idx+1}')
    plt.tight_layout()
    plt.show()
"""
#for now leave away similarity clustering, maybe better after recombination
# Out:
# "import torch\nimport matplotlib.pyplot as plt\n\n#Parameters\nimgs = [x.clamp(0, 1) for x in contribs_imgs]\nvalue_thresh = 0.9\nloc_thresh = 3\ngroups = []\nused = set()\n\n\n\nfor g_idx, group in enumerate(groups):\n    plt.figure(figsize=(len(group)*2, 2))\n    for idx, img_idx in enumerate(group):\n        plt.subplot(1, len(group), idx + 1)\n        plt.imshow(imgs[img_idx].squeeze(), cmap='inferno', vmin=0, vmax=1)\n        plt.axis('off')\n    plt.suptitle(f'Group {g_idx+1}')\n    plt.tight_layout()\n    plt.show()\n"

# %%
#recombine in next layer l+1

# %%
weights_fc1 = net.fc1.weight.detach().cpu()
concepts = contribs_imgs

# %%
weights_exp = weights_fc1.unsqueeze(-1).unsqueeze(-1)
concepts_exp = concepts.unsqueeze(0)
combined = (weights_exp * concepts_exp).sum(dim=1)

# %%
#normalise to [0, 1]
max_val = combined.max()
combined = combined / max_val
#combined = combined.view(-1, 28, 28)

biases_fc1 = net.fc1.bias.detach().cpu()
combined += biases_fc1[:, None, None]

combined = torch.where(
    combined == 0,
    torch.tensor(0.0, device=combined.device),
    torch.where(
        combined > 0.35,
        combined,
        torch.tensor(0.1, device=combined.device)
    ) 
)

# %%
weights_fc2 = net.fc2.weight.detach().cpu()

# %%
import torch.nn.functional as F
import math

# %%
with torch.no_grad():
    x = img.view(1, -1).cuda()
    a0 = F.tanh(net.fc0(x)) #using tanh because ReLU bad for explainability, issue because -a*(-w) = z > 0, but becomes 0 due to ReLU
    a1 = F.tanh(net.fc1(a0)) #would have been positive activation and useful to explanaiton
    logits_fc2 = net.fc2(a1)

print(a1.size())
print(f"out: {logits_fc2.item()}")
sign = 0 if logits_fc2.item() > 0 else 1
print(f"Net predicted img was {sign*'not '}a {"trained_dig"}")
# Out:
# torch.Size([1, 16])
# out: -7.164858818054199
# Net predicted img was not a 3

# %%
fig, axes = plt.subplots(4, 4, figsize=(12, 12))
for idx, ax in enumerate(axes.flat):  
    ax.imshow(combined[idx].cpu(), cmap='inferno')
    ax.axis('off')
    ax.set_title(f'Neuron {idx}\nWeight: {round(weights_fc2[0][idx].item(), 5)}\nActivation: {round(a1[0][idx].item(), 5)}\nAct. after fc2: {round(weights_fc2[0][idx].item() * a1[0][idx].item(), 5)}')
plt.tight_layout()
plt.show()

bias_fc2 = net.fc2.bias.detach().cpu()
print(bias_fc2)

#concepts after fc1
# Out:
# tensor([0.1860])

# %%
#Important Note, I learned:
#A trait of a digit may contribute negatively to decision that it is that digit, and only in last layer flip sign to contribute positively, due to both negative weight and activation!
#clearly seen here!

#(unless using ReLU)

########################
#concepts for the trained digits have positive contribution, other negative, in principle teh net checks for the presence of these concepts

# %% [markdown]
# Idea: Trace back concepts from fc2 to fc1 and then label the importance of a concept (not just pixel values) in the input image, with a section color for clear conceptual and segmented explanation

# %%
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        mask = (labels != -1)
        if not mask.any():
            continue
        images = images[mask]
        if CUDA:
            images = images.cuda()
        images = images.view(-1, 28*28)

        a0 = F.tanh(net.fc0(images))
        a1 = F.tanh(net.fc1(a0))
        logits = net.fc2(a1)
        predicted = (torch.sigmoid(logits) >= 0.5).float()

        correct += predicted.sum().item()
        total += images.size(0)

    print(f'Accuracy on digit {"trained_dig"} (manual pass with activations): {100 * correct / total:.2f} %')
# Out:
# Accuracy on digit trained_dig (manual pass with activations): 527.54 %

# %%
#note: before adjusting dataset not to be biased to many more non-bin_digit's in proportion, using ReLU was needed, 
#because it would make negative contributions that were only <0 because the net was biased, trained on uneven data, but now that the dataset is fixed,
#ReLU is hurting the explainability and tanh or even no activation function at all is giving higher accuracy!

# %%
#input segmentation with importance, influence, color attribution in plot for clear overview, after that: implement recreation with new algorithm

combo = torch.where(
        combo > 0.0,
        combo,
        torch.tensor(0.0, device=combined.device)
    )

plt.imshow(combo, cmap="inferno")
plt.title("most important 50% of pixels")

#-> segment this
# Out:
# Text(0.5, 1.0, 'most important 50% of pixels')

# %%
pixel_count = combo.view(-1).size()[0]
pixel_count_important = (combo > 0).sum().item()
segment_size = round(pixel_count_important * 0.075, 0)
pixel_count_important, segment_size
# Out:
# (161, 12.0)

# %%
imp_pixels = (combo > 0).nonzero(as_tuple=False) #tensor of coordiantes that aren't = 0

# %%
from sklearn.cluster import AgglomerativeClustering
from collections import defaultdict
from scipy.spatial.distance import cdist
import numpy as np
import matplotlib.patches as mpatches

# %%
clusterer = AgglomerativeClustering(
    n_clusters=None,
    distance_threshold=segment_size,
    linkage='complete',
    metric='euclidean'
)
labels = clusterer.fit_predict(imp_pixels)

clusters = defaultdict(list)
for coord, label in zip(imp_pixels, labels):
    clusters[label].append(coord)

#making a map
label_map = torch.zeros((28, 28), dtype=torch.int32)
for label, coords in clusters.items():
    for y, x in coords:
        label_map[y, x] = label + 1

label_map_np = label_map.numpy()
unique_vals = np.unique(label_map_np)

plt.figure(figsize=(5, 5))
plt.imshow(label_map_np, cmap='inferno', interpolation='nearest')
plt.axis('off')
plt.title('Spatially Grouped Important Pixels')

for val in unique_vals:
    positions = np.argwhere(label_map_np == val)
    if positions.size == 0 or val == 0:
        continue
    centroid = positions.mean(axis=0)
    y, x = centroid
    plt.text(x, y, str(val-1), color='lightgray', fontsize=20, ha='center', va='center')

plt.show()

# %%
label_neuron_dict = {}

for label in set(labels):
    label_neuron_dict[label] = {}

for coord, label in zip(imp_pixels, labels):
    y, x = coord
    for idx, neuron_map in enumerate(contribs_imgs):
        val = neuron_map[y, x]
        if val > 0.6:
            label_neuron_dict[label][idx] = label_neuron_dict[label].get(idx, 0) + val


sorted_label_neuron = {
  label: sorted(neurons.items(), key=lambda item: item[1], reverse=True)
  for label, neurons in label_neuron_dict.items()
}
sorted_label_neuron
# Out:
# {0: [(26, tensor(2.5013)),
#   (10, tensor(0.6948)),
#   (7, tensor(0.6866)),
#   (2, tensor(0.6824)),
#   (24, tensor(0.6437)),
#   (14, tensor(0.6323)),
#   (0, tensor(0.6000))],
#  1: [(24, tensor(2.3465)),
#   (3, tensor(1.5106)),
#   (19, tensor(1.3674)),
#   (15, tensor(1.3317)),
#   (4, tensor(0.7438)),
#   (31, tensor(0.6739)),
#   (13, tensor(0.6470)),
#   (20, tensor(0.6388)),
#   (30, tensor(0.6352)),
#   (6, tensor(0.6343))],
#  2: [],
#  3: [(10, tensor(2.8231)), (20, tensor(0.6315)), (26, tensor(0.6192))]}

# %%
def meshgrid(size):
    y, x = torch.meshgrid(torch.arange(size), torch.arange(size), indexing='ij')
    return x, y

def circle(size, radius, angle_range, center, thickness):
    x, y = meshgrid(size)
    dx = x - center[0]
    dy = y - center[1]
    dist = torch.sqrt(dx**2 + dy**2)
    angles = torch.atan2(dy, dx) * 180 / torch.pi % 360
    angle_min, angle_max = angle_range
    angle_mask = (angles >= angle_min) & (angles <= angle_max) if angle_min < angle_max else \
                 (angles >= angle_min) | (angles <= angle_max)
    circle_mask = ((dist >= radius - thickness / 2) & (dist <= radius + thickness / 2)) & angle_mask
    return circle_mask.float()

def line(size, length, angle, center, thickness):
    x, y = meshgrid(size)
    angle_rad = torch.tensor(angle) * torch.pi / 180
    dx = torch.cos(angle_rad)
    dy = torch.sin(angle_rad)
    x0 = center[0] - dx * length / 2
    y0 = center[1] - dy * length / 2
    x1 = center[0] + dx * length / 2
    y1 = center[1] + dy * length / 2
    px = x - x0
    py = y - y0
    proj = (px * dx + py * dy).clamp(0, length)
    closest_x = x0 + proj * dx
    closest_y = y0 + proj * dy
    dist = torch.sqrt((x - closest_x) ** 2 + (y - closest_y) ** 2)
    return (dist <= thickness / 2).float()

"""def cross(size, length, angle, center, thickness):
    l1 = line(size, length, angle, center, thickness)
    l2 = line(size, length, angle + 90, center, thickness)
    return (l1 + l2).clamp(0, 1)"""
# Out:
# 'def cross(size, length, angle, center, thickness):\n    l1 = line(size, length, angle, center, thickness)\n    l2 = line(size, length, angle + 90, center, thickness)\n    return (l1 + l2).clamp(0, 1)'

# %%
import matplotlib.pyplot as plt

#Create the concept tensors
C = circle(size=30, radius=15, angle_range=(230, 310), center=(10, 20), thickness=1.0)
L = line(size=28, length=10, angle=20, center=(14, 14), thickness=1.5)
#X = cross(size=28, length=18, angle=130, center=(14, 10), thickness=1.5)

#Plotting
fig, axs = plt.subplots(1, 2, figsize=(6, 3))
axs[0].imshow(C, cmap='gray')
axs[0].set_title('Circle (Arc)')
axs[1].imshow(L, cmap='gray')
axs[1].set_title('Line')
#axs[2].imshow(X, cmap='gray')
#axs[2].set_title('Cross')

for ax in axs:
    ax.axis('off')
plt.tight_layout()
plt.show()


########
#circle still a bit  in accurate, bad for relation testing

# %%
#now apply to activated parts of input to represent it with these concepts, do that for many input
#then for each input example find relation rules and based on all data the limits
#apply these limit rules to predict digit without FFN

# %%
import numpy as np
import cv2
from skimage.morphology import skeletonize
import matplotlib.pyplot as plt
import random as ra

# %%
#this code cell is only for segmentation and not my personal code

def neighbors_8(img, y, x):
    h, w = img.shape
    for ny in range(max(y-1,0), min(y+2,h)):
        for nx in range(max(x-1,0), min(x+2,w)):
            if (ny, nx) != (y, x):
                yield ny, nx

def find_primary_continuous_path(skeleton_image):
    if not np.any(skeleton_image):
        return []

    active_pixels = set(zip(*np.where(skeleton_image)))
    if not active_pixels:
        return []

    start_point = None
    for r, c in active_pixels:
        count = sum(1 for nr, nc in neighbors_8(skeleton_image, r, c) if skeleton_image[nr, nc])
        if count <= 1:
            start_point = (r, c)
            break
    if not start_point:
        start_point = next(iter(active_pixels))
        
    path = []
    visited = set()
    stack = [start_point]

    while stack:
        current_pixel = stack.pop()
        
        if current_pixel in visited:
            continue
        
        visited.add(current_pixel)
        path.append(current_pixel)

        unvisited_neighbors = []
        for ny, nx in neighbors_8(skeleton_image, *current_pixel):
            if skeleton_image[ny, nx] and (ny, nx) not in visited:
                unvisited_neighbors.append((ny, nx))
        
        for neighbor in unvisited_neighbors:
            stack.append(neighbor)

    return path

def bresenham_line(y0, x0, y1, x1):
    points = []
    dy = abs(y1 - y0)
    dx = abs(x1 - x0)
    sy = 1 if y0 < y1 else -1
    sx = 1 if x0 < x1 else -1
    err = dx - dy
    while True:
        points.append((y0, x0))
        if y0 == y1 and x0 == x1:
            break
        e2 = 2 * err
        if e2 > -dy:
            err -= dy
            x0 += sx
        if e2 < dx:
            err += dx
            y0 += sy
    return points

def segment_only_on_white_pixels(start, end, skeleton):
    points_on_line = bresenham_line(start[0], start[1], end[0], end[1])
    return all(skeleton[y, x] != 0 for y, x in points_on_line)

def line_approximation_with_corners(path, angle_tolerance_degrees=20):
    segments = []
    if len(path) < 2:
        return segments

    current_segment_start_point = path[0]

    for i in range(1, len(path)):
        current_point_on_path = path[i]

        if i == len(path) - 1:
            if segment_only_on_white_pixels(current_segment_start_point, current_point_on_path, skeleton):
                segments.append((current_segment_start_point, current_point_on_path))
            break

        next_point_on_path = path[i + 1]

        v1 = np.array(current_point_on_path) - np.array(current_segment_start_point)
        v2 = np.array(next_point_on_path) - np.array(current_point_on_path)

        if np.linalg.norm(v1) == 0 or np.linalg.norm(v2) == 0:
            continue

        dot_product = np.dot(v1, v2)
        magnitude_v1 = np.linalg.norm(v1)
        magnitude_v2 = np.linalg.norm(v2)

        cos_theta = max(-1.0, min(1.0, dot_product / (magnitude_v1 * magnitude_v2)))

        angle_radians = math.acos(cos_theta)
        angle_degrees = math.degrees(angle_radians)

        is_corner = (angle_degrees > angle_tolerance_degrees and
                     angle_degrees < (180 - angle_tolerance_degrees))

        if is_corner or not segment_only_on_white_pixels(current_segment_start_point, current_point_on_path, skeleton):
            if segment_only_on_white_pixels(current_segment_start_point, current_point_on_path, skeleton):
                segments.append((current_segment_start_point, current_point_on_path))
            current_segment_start_point = current_point_on_path

    if current_segment_start_point != path[-1] or not segments:
        if len(path) > 1 and (not segments or segments[-1][1] != path[-1]):
            if segment_only_on_white_pixels(current_segment_start_point, path[-1], skeleton):
                segments.append((current_segment_start_point, path[-1]))

    return segments

# %%
#data prep
inputs, labels = next(iter(train_loader))
dig_to_check = 5
while True:
    ind = ra.randrange(len(inputs))
    if labels[ind] == dig_to_check:
        img = inputs[ind].squeeze()
        break

img = torch.where(img > img.max()*0.3, 255, 0).to(torch.uint8)
inp = img.cpu().numpy()

#segmnetation
skeleton = skeletonize(inp // 255).astype(np.uint8)
continuous_pixel_path = find_primary_continuous_path(skeleton)
line_segments = line_approximation_with_corners(continuous_pixel_path, angle_tolerance_degrees=20)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(inp, cmap='gray')
plt.title(f'Original Digit (Label: {dig_to_check})')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(np.zeros_like(inp), cmap='gray') 
plt.title('Approximated Line Segments')

concept_coords = np.empty((0, 2))

for start_p, end_p in line_segments:
    plt.plot([start_p[1], end_p[1]], [start_p[0], end_p[0]], 'r-', linewidth=2)
    concept_coords = np.append(concept_coords, np.array([start_p, end_p]), axis=0)
plt.axis('off')

plt.tight_layout()
plt.show()

concept_coords
# Out:
# array([[ 6., 18.],
#        [ 6., 16.],
#        [ 6., 16.],
#        [ 7., 15.],
#        [ 7., 15.],
#        [ 7., 12.],
#        [ 7., 12.],
#        [ 8., 11.],
#        [ 8., 11.],
#        [ 8.,  7.],
#        [ 8.,  7.],
#        [ 9.,  6.],
#        [ 9.,  6.],
#        [11.,  6.],
#        [11.,  6.],
#        [12.,  7.],
#        [12.,  7.],
#        [12., 18.],
#        [12., 18.],
#        [13., 19.],
#        [13., 19.],
#        [13., 20.],
#        [13., 20.],
#        [14., 21.],
#        [14., 21.],
#        [14., 22.],
#        [14., 22.],
#        [15., 23.],
#        [15., 23.],
#        [18., 23.],
#        [18., 23.],
#        [19., 22.],
#        [19., 22.],
#        [20., 22.],
#        [20., 22.],
#        [21., 21.],
#        [21., 21.],
#        [21., 19.],
#        [21., 19.],
#        [22., 18.],
#        [22., 18.],
#        [22., 17.],
#        [22., 17.],
#        [23., 16.],
#        [23., 16.],
#        [23., 14.],
#        [23., 14.],
#        [22., 13.],
#        [22., 13.],
#        [22., 11.],
#        [22., 11.],
#        [21., 10.],
#        [21., 10.],
#        [21.,  9.],
#        [21.,  9.],
#        [20.,  8.],
#        [ 8.,  6.],
#        [ 6.,  6.]])

# %%
#next: teach algo to recognize concepts so it can test their relations for classification
